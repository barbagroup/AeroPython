# %% [raw]
# Text provided under a Creative Commons Attribution license, CC-BY 4.0 Code under MIT license (c)2014 Lorena A. Barba, Olivier Mesnard. Thanks: NSF for support via CAREER award #1149784.

# %% [markdown]
# [@LorenaABarba](https://twitter.com/LorenaABarba)

# %% [markdown]
# ##### Version 0.2 -- February 2014

# %% [markdown]
# # Source Sheet

# %% [markdown]
# A source sheet is an infinite row of sources along one line. You have already created a vortex sheet by placing a row of vortices on one line, so you are ready for this.
#
# We start by importing our libraries and creating the grid of points, as before.

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import *

# %%
N = 100                            # Number of points in each direction
xStart,xEnd = -1.0,1.0            # x-direction boundaries
yStart,yEnd = -1.5,1.5            # y-direction boundaries
x = np.linspace(xStart,xEnd,N)    # x 1D-array
y = np.linspace(yStart,yEnd,N)    # y 1D-array
X,Y = np.meshgrid(x,y)            # generation of the mesh grid

# %% [markdown]
# We will consider a uniform flow of magnutide $U_\infty = 1$ parallel to the horizontal axis. The arrays `uFreestream` and `vFreestream` represents the velocity components.

# %%
Uinf = 1.0

uFreestream = Uinf*np.ones((N,N),dtype=float)
vFreestream = np.zeros((N,N),dtype=float)

# %% [markdown]
# ### Finite number of sources along a line

# %% [markdown]
# We consider first a finite number of sources arranged along a line normal to the freestream. The streamlines will come out of each source and be deflected by the streamlines coming from the freestream.
#
# From a computational poit of view, the finite number of sources can be represented by a 1D-array containing objects, each one being an instanciation of the class `Source`. This class should have as attributes the strength of a source `strength`, its location (`x`,`y`), and a method to compute the velocity components on a given mesh grid (`X`,`Y`).

# %%
class Source:
    def __init__(self,strength,x,y):
        self.strength = strength
        self.x,self.y = x,y
    # get the velocity field
    def velocity(self,X,Y):
        self.u = self.strength/(2*pi)*(X-self.x)/((X-self.x)**2+(Y-self.y)**2)
        self.v = self.strength/(2*pi)*(Y-self.y)/((X-self.x)**2+(Y-self.y)**2)
    # get the stream-function
    def streamFunction(self,X,Y):
        self.psi = self.strength/(2*pi)*np.arctan2((Y-self.y),(X-self.x))

# %%
# definition of my sources
NSource = 11
strength = 5.0
strengthSource = strength/NSource
xSource = 0.0
ySource = np.linspace(-1.0,1.0,NSource)

# creation of the source line
source = np.empty(NSource,dtype=object)
for i in range(NSource):
    source[i] = Source(strengthSource,xSource,ySource[i])
    source[i].velocity(X,Y)

# superposition
u = uFreestream.copy()
v = vFreestream.copy()

for s in source:
    u = np.add(u,s.u)
    v = np.add(v,s.v)

# %% [markdown]
# The flow pattern corresponds to the superposition of a uniform flow and `NSource` identical sources of strength `strengthSource` equally spaced along a vertical line normal to the uniform flow. Red points represent the sources and we also define a filled contour of velocity magnitude to visualize the location of the stagnation point, defined by $u=0$ and $v=0$.

# %%
# plotting
size = 8
plt.figure(figsize=(size,(yEnd-yStart)/(xEnd-xStart)*size))
plt.grid(True)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.xlim(xStart,xEnd)
plt.ylim(yStart,yEnd)
plt.streamplot(X,Y,u,v,density=3,linewidth=1,arrowsize=1,arrowstyle='->')
plt.scatter(xSource*np.ones(NSource,dtype=float),ySource,c='#CD2305',s=80,marker='o')
cont = plt.contourf(X,Y,np.sqrt(u**2+v**2),levels=np.linspace(0.0,0.1,10))
cbar = plt.colorbar(cont)
cbar.set_label('U',fontsize=16);

# %% [markdown]
# Change the number of sources along the line. What difference do you see?

# %% [markdown]
# Now try to change the total strength of the sources. What is the minimal total source strength so that the dividing streamline ($\psi = 0$) encloses all the singularities?

# %% [markdown]
# ### Source sheet

# %% [markdown]
# By definition, a source sheet is an infinite collection of side-by-side sources of infinitesimal equal strength distributed along a given path.
#
# Considering that $s$ is the running coordinate along the sheet, we define $\sigma = \sigma(s)$ as the strength per unit length.
#
# We should recall that the strength of a single source represents the volume flow rate per unit depth (i.e. per unit length in the $z$-direction).
# Therefore $\sigma$ represents the volume flow rate per unit depth and per unit length (in the $s$-direction). Thus, $\sigma ds$ is the strength of an infinitesimal portion $ds$ of the sheet. This infinitesiaml portion is so small that it can be treated a distinct source of strength $\sigma ds$.
#
# Following this, the stream-function at point $\left(r,\theta\right)$ of this inifnitesimal portion is
#
# $$d\psi\left(r,\theta\right) = \frac{\sigma ds}{2\pi} \theta$$
#
# Integration along $s$, we find the stream-function of the entire source sheet:
#
# $$\psi\left(r,\theta\right) = \frac{\sigma}{2\pi}\int_{\text{sheet}}\theta\left(s\right)ds$$
#
# In the previous section, we considered a vertical finite distribution. Keeping this idea, the stream-function of a vertical source sheet at $x=0$ between $y_{\text{min}}$ and $y_{\text{max}}$ in Cartesian coordinates is
#
# $$\psi\left(x,y\right) = \frac{\sigma}{2\pi}\int_{y_{\text{min}}}^{y_{\text{max}}} \tan^{-1}\left(\frac{y-\xi}{x}\right)d\xi$$
#
# And by derivation, once can get the velocity components
#
# $$u\left(x,y\right) = \frac{\sigma}{2\pi} \int_{y_{\text{min}}}^{y_{\text{max}}} \frac{x}{x^2+\left(y-\xi\right)^2}d\xi$$
#
# $$v\left(x,y\right) = \frac{\sigma}{2\pi} \int_{y_{\text{min}}}^{y_{\text{max}}} \frac{y-\xi}{x^2+\left(y-\xi\right)^2}d\xi$$

# %% [markdown]
# The compute the velocities, the two integrals above need to be calculated. To do that, we are going to use the module `integrate` from the library SciPy, a fundamental library for scientific computing.

# %%
from scipy import integrate

# %% [markdown]
# The function `quad(func,a,b)` of the module `integrate` compute the integral of `func` from `a` to `b`.
#
# To define the function to integrate, we use the keyword `lambda` that allows to create small anonymous functions. Lets consider the example of an addition to explain this new keyword:

# %%
a = 1.0
f = lambda x : x+a
print 'x + a =',f(1)
# Out:
# x + a = 2.0

# %% [markdown]
# Suppose we want to integrate the function $f:x\rightarrow x$ from $0$ to $1$. We should expect the function `quad()` to return the value $0.5$.

# %%
print integrate.quad(lambda x : x, 0.0, 1.0)[0]
# Out:
# 0.5

# %% [markdown]
# Note that the function `quad()` returns a list, the first element being the result of the integral.

# %%
sigma = 2.5    # strength of the source sheet

uPanel    = np.empty((N,N),dtype=float)
vPanel    = np.empty((N,N),dtype=float)

# boundaries of the sheet
ymin,ymax = -1.0,1.0

# computing the velocity field
for i in range(N):
    for j in range(N):
        
        func = lambda s : X[i,j]/(X[i,j]**2+(Y[i,j]-s)**2)
        uPanel[i,j] = sigma/(2*pi)*integrate.quad(func,ymin,ymax)[0]
        
        func = lambda s:(Y[i,j]-s)/(X[i,j]**2+(Y[i,j]-s)**2)
        vPanel[i,j] = sigma/(2*pi)*integrate.quad(func,ymin,ymax)[0]

# superposition to the uniform flow
u2   = np.add(uFreestream,uPanel)
v2   = np.add(vFreestream,vPanel)

# %% [markdown]
# Lets visualize the streamlines (blue) on the mesh grid. The red line defines the source sheet and the filled contour allows us to visualize the location of the stagnation point.

# %%
# plotting
size = 8
plt.figure(figsize=(size,(yEnd-yStart)/(xEnd-xStart)*size))
plt.grid(True)
plt.xlabel('x',fontsize=16)
plt.ylabel('y',fontsize=16)
plt.xlim(xStart,xEnd)
plt.ylim(yStart,yEnd)
plt.streamplot(X,Y,u2,v2,density=2,linewidth=1,arrowsize=1,arrowstyle='->')
plt.axvline(0.0,(ymin-yStart)/(yEnd-yStart),(ymax-yStart)/(yEnd-yStart),\
            color='#CD2305',linewidth=4)
cont = plt.contourf(X,Y,np.sqrt(u2**2+v2**2),levels=np.linspace(0.0,0.1,10))
cbar = plt.colorbar(cont)
cbar.set_label('U',fontsize=16);

# %% [markdown]
# We said that the strength $\sigma$ represents a volume flow rate emanating from the source sheet. If you play we this parameter, you will see that the stagnation point becomes closer and closer to the source sheet if by decreasing the strength.
#
# If we want to use multiple source sheets to represents the streamlines around a given body shape, we need to make each source sheet part of the divinding streamline. What is the strength value to make this happening?
#
# The volume flow rate only on the left side of the sheet is $\frac{\sigma}{2}$ going in the opposite direction of the freestream velocity $U_\infty$.
# Therefore, the flow tangency boundary condition (i.e. no penetration) required is $\frac{\sigma}{2} = U_\infty$.
#
# Now go back to the code above an replace the `sigma` by the correct value. Where is the stagnation point? Where is the dividing streamline?

# %% [markdown]
# ---

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open('./styles/custom.css', 'r').read()
    return HTML(styles)
css_styling()
# Out:
# <link href='http://fonts.googleapis.com/css?family=Fenix' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Source+Code+Pro:300,400' rel='stylesheet' type='text/css'>
# <style>
#     @font-face {
#         font-family: "Computer Modern";
#         src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
#     }
#     div.cell{
#         width:800px;
#         margin-left:16% !important;
#         margin-right:auto;
#     }
#     h1 {
#         font-family: 'Alegreya Sans', sans-serif;
#     }
#     h2 {
#         font-family: 'Fenix', serif;
#     }
#     h3{
# 		font-family: 'Fenix', serif;
#         margin-top:12px;
#         margin-bottom: 3px;
#        }
# 	h4{
# 		font-family: 'Fenix', serif;
#        }
#     h5 {
# ...
